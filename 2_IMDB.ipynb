# %%
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Flatten, Input

# %%
vocab_size = 10000

(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocab_size)

# %%
max_len = 200

X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# %%
model = Sequential([
    Input(shape=(max_len,)),
    
    Embedding(input_dim=vocab_size, output_dim=32),
    Flatten(),
    
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    
    Dense(1, activation='sigmoid')   # binary output
])

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(
    X_train, y_train,
    epochs=5,
    batch_size=128,
    validation_split=0.2
)
# Out:
# Epoch 1/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.7315 - loss: 0.4953 - val_accuracy: 0.8626 - val_loss: 0.3192
# Epoch 2/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.9352 - loss: 0.1761 - val_accuracy: 0.8530 - val_loss: 0.3537
# Epoch 3/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.9926 - loss: 0.0340 - val_accuracy: 0.8566 - val_loss: 0.4449
# Epoch 4/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.9985 - loss: 0.0080 - val_accuracy: 0.8462 - val_loss: 0.5276
# Epoch 5/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8554 - val_loss: 0.5631

# %%
loss, acc = model.evaluate(X_test, y_test)

print("Test Accuracy:", acc)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8524 - loss: 0.5742
# Test Accuracy: 0.852400004863739

# %%
pred = model.predict(X_test[:5])

print(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# [[2.8838429e-03]
#  [9.9991238e-01]
#  [9.7589362e-01]
#  [4.3498096e-04]
#  [9.9992704e-01]]
